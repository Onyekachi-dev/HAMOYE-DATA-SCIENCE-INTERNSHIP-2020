# %% [markdown]
# # SOLUTION TO QUIZ

# %%
#Introduction to Python Machine learning quiz solutionsfor STAGE A of Hamoye Data science internship programme

# %%
#First step in writing a code using is to import all required library packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
#Question 1 is A.extend(B)
#please find the solution below

A = [1,2,3,4,5,6]
B = [13, 21, 34]

# %%
A.extend(B)

# %%
A_B = A

# %%
A_B
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
#Answer to question 2 is np.identity(3)
#please find the solution below

np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
#the second step is to download the dataset to be analyzed 
df = pd.read_csv("https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv")
df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
#Question 3

dfs= df.groupby('fuel_type_code_pudl').mean()

# %%
dfs['fuel_cost_per_unit_burned']
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
#Question 4

df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
#Question 5
df['fuel_qty_burned'].skew()
# Out:
# 15.851495469109503

# %%
#Question 5
df['fuel_qty_burned'].kurt()
# Out:
# 651.3694501337732

# %%
#Question 6
#please find solution below

df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
#To check the length of the dataframe

len(df)
# Out:
# 29523

# %%
#To calculate teh percentage pf missing data

round(((180/29523)*100),3)
# Out:
# 0.61

# %%
#Question 7
dfs = df.groupby('fuel_unit')

# %%
dfs['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
df['fuel_unit'].fillna(value='mcf', inplace=True)

# %%
df.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
#Question 8
df.corr()['fuel_cost_per_unit_burned']
# Out:
# utility_id_ferc1               -0.037863
# report_year                     0.013599
# fuel_qty_burned                -0.018535
# fuel_mmbtu_per_unit            -0.010034
# fuel_cost_per_unit_burned       1.000000
# fuel_cost_per_unit_delivered    0.011007
# fuel_cost_per_mmbtu            -0.000437
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
#Question 9
dfs= df.groupby('report_year').mean()

# %%
dfs
# Out:
#              utility_id_ferc1  fuel_qty_burned  fuel_mmbtu_per_unit  \
# report_year
# 1994               106.120648     2.724018e+06            10.638098
# 1995               110.139051     3.712067e+06            10.644830
# 1996               108.714154     2.544754e+06            10.778041
# 1997               108.366545     2.813503e+06            10.247632
# 1998               109.845528     3.267453e+06            10.704964
# 1999               108.222857     3.281281e+06            10.558885
# 2000               111.083758     2.472032e+06             9.224475
# 2001               113.521386     2.321402e+06             8.371469
# 2002               120.354357     2.145645e+06             8.304833
# 2003               123.300578     1.888622e+06             8.403746
# 2004               121.123322     1.782547e+06             8.332425
# 2005               121.028369     1.768876e+06             8.135972
# 2006               117.178600     1.957264e+06             8.138090
# ...

# %%
#Question 9

((126.683519-213.191996)/213.191996)*100
# Out:
# -40.577732102100114

# %%
#Question 10

dfs
# Out:
#              utility_id_ferc1  fuel_qty_burned  fuel_mmbtu_per_unit  \
# report_year
# 1994               106.120648     2.724018e+06            10.638098
# 1995               110.139051     3.712067e+06            10.644830
# 1996               108.714154     2.544754e+06            10.778041
# 1997               108.366545     2.813503e+06            10.247632
# 1998               109.845528     3.267453e+06            10.704964
# 1999               108.222857     3.281281e+06            10.558885
# 2000               111.083758     2.472032e+06             9.224475
# 2001               113.521386     2.321402e+06             8.371469
# 2002               120.354357     2.145645e+06             8.304833
# 2003               123.300578     1.888622e+06             8.403746
# 2004               121.123322     1.782547e+06             8.332425
# 2005               121.028369     1.768876e+06             8.135972
# 2006               117.178600     1.957264e+06             8.138090
# ...

# %%
#Question 10

dfs['fuel_cost_per_unit_delivered']
# Out:
# report_year
# 1994       63.636060
# 1995       32.735269
# 1996     9196.705948
# 1997    11140.197239
# 1998      287.154420
# 1999       25.551627
# 2000      985.362877
# 2001       60.050396
# 2002       47.594361
# 2003       55.663493
# 2004      139.524275
# 2005       41.438184
# 2006       38.657484
# 2007       43.325023
# 2008       58.588197
# 2009      652.694163
# 2010       91.862105
# 2011       59.774667
# 2012       60.994502
# 2013      172.307591
# 2014      192.737183
# 2015      326.535511
# 2016      103.901761
# 2017       46.196861
# 2018      499.269966
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS FOR DATA SET fuel_ferc1¶
# Exploratory Data Analysis is an approach to analyzing data sets to summarize their main characteristics often with visual methods. The main purpose of exploratory data analysis is to check for missing data and other mistakes.gain maximum insight into the data set and its underlying structure.

# %%
df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
#This code prints out the first five rows of all dataframe element

df.head(5)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
#This code brings out the last five rows of all dataframe element

df.tail(5)
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 29518    neil simpson ct #1                 gas       mcf          18799.0
# 29519  cheyenne prairie 58%                 gas       mcf         806730.0
# 29520     lange ct facility                 gas       mcf         104554.0
# 29521       wygen 3 bhp 52%                coal       ton         315945.0
# 29522       wygen 3 bhp 52%                 gas       mcf          17853.0
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 29518                1.059                       4.78
# ...

# %% [markdown]
# # DATA WRANGLING

# %%
#This code gives details of the datatype of each column
df.dtypes
# Out:
# record_id                        object
# utility_id_ferc1                  int64
# report_year                       int64
# plant_name_ferc1                 object
# fuel_type_code_pudl              object
# fuel_unit                        object
# fuel_qty_burned                 float64
# fuel_mmbtu_per_unit             float64
# fuel_cost_per_unit_burned       float64
# fuel_cost_per_unit_delivered    float64
# fuel_cost_per_mmbtu             float64
# dtype: object

# %%
#describes all the numerical variables of the dataframe
df.describe(include='all')
# Out:
#                      record_id  utility_id_ferc1   report_year  \
# count                    29523      29523.000000  29523.000000
# unique                   29523               NaN           NaN
# top     f1_fuel_1996_12_81_0_1               NaN           NaN
# freq                         1               NaN           NaN
# mean                       NaN        118.601836   2005.806050
# std                        NaN         74.178353      7.025483
# min                        NaN          1.000000   1994.000000
# 25%                        NaN         55.000000   2000.000000
# 50%                        NaN        122.000000   2006.000000
# 75%                        NaN        176.000000   2012.000000
# max                        NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29523     2.952300e+04
# ...

# %%
#This code prints out the names of features in the dataset
df.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
#this code tells us the dimension of the dataframei.e length of rows and columns
df.shape
# Out:
# (29523, 11)

# %%
#This codes obtains dataframe with missing row and column(feature) values
df.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
#this code is used for finding the frequency of the values  present in a particular column, in this case the missing data in the fuel_unit column 
df['fuel_unit'].value_counts()
# Out:
# mcf       11534
# ton        8958
# bbl        7998
# gramsU      464
# mmbtu       180
# kgU         110
# mwhth       100
# mwdth        95
# gal          84
# Name: fuel_unit, dtype: int64

# %%
#In a bid to speculate the missing values, we can compare the column that has the missing value with a similar one 
#See code below where I compared 'fuel_unit' to 'plant_name_ferc1'

df[['plant_name_ferc1','fuel_unit']][df.fuel_unit.isnull()]
# Out:
# Empty DataFrame
# Columns: [plant_name_ferc1, fuel_unit]
# Index: []

# %%
#This code removes all rows with a missing value
df.dropna()
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
df.count()
# Out:
# record_id                       29523
# utility_id_ferc1                29523
# report_year                     29523
# plant_name_ferc1                29523
# fuel_type_code_pudl             29523
# fuel_unit                       29523
# fuel_qty_burned                 29523
# fuel_mmbtu_per_unit             29523
# fuel_cost_per_unit_burned       29523
# fuel_cost_per_unit_delivered    29523
# fuel_cost_per_mmbtu             29523
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %%
#iloc()function gets integer location rows(or columns)in the index i.e location based indexing
df.iloc[3]
# Out:
# record_id                       f1_fuel_1994_12_2_0_7
# utility_id_ferc1                                    2
# report_year                                      1994
# plant_name_ferc1                                barry
# fuel_type_code_pudl                              coal
# fuel_unit                                         ton
# fuel_qty_burned                           3.73948e+06
# fuel_mmbtu_per_unit                             23.95
# fuel_cost_per_unit_burned                       47.21
# fuel_cost_per_unit_delivered                    45.99
# fuel_cost_per_mmbtu                              1.97
# Name: 3, dtype: object

# %%
#loc function is label based which means you specify rows and columns based on theirnrow and column labels
df.loc[12]
# Out:
# record_id                       f1_fuel_1994_12_4_0_5
# utility_id_ferc1                                    4
# report_year                                      1994
# plant_name_ferc1                               unit 4
# fuel_type_code_pudl                               gas
# fuel_unit                                         mcf
# fuel_qty_burned                                  6673
# fuel_mmbtu_per_unit                             1.026
# fuel_cost_per_unit_burned                        1.94
# fuel_cost_per_unit_delivered                     1.94
# fuel_cost_per_mmbtu                               1.9
# Name: 12, dtype: object

# %%
#the groupby functions helps to restructure dateframe using the intended feature
gb = df.groupby('utility_id_ferc1')

# %%
gb.get_group(12).set_index('plant_name_ferc1').head()
# Out:
#                                 record_id  utility_id_ferc1  report_year  \
# plant_name_ferc1
# ben french         f1_fuel_1994_12_12_0_3                12         1994
# bf station         f1_fuel_1994_12_12_0_7                12         1994
# bf station         f1_fuel_1994_12_12_0_8                12         1994
# bf station         f1_fuel_1994_12_12_0_9                12         1994
# osage plant       f1_fuel_1994_12_12_0_11                12         1994
#
#                  fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# plant_name_ferc1
# ben french                       gas       mcf          64478.0
# bf station                      coal       ton         133867.0
# bf station                       oil       bbl           2201.0
# bf station                       gas       mcf           5169.0
# osage plant                     coal       ton         205675.0
#
#                   fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# plant_name_ferc1
# ...

# %%
gb = df.groupby('report_year')

# %%
gb.get_group(2018).set_index('record_id').head(5)
# Out:
#                          utility_id_ferc1  report_year plant_name_ferc1  \
# record_id
# f1_fuel_2018_12_122_0_2               122         2018        big stone
# f1_fuel_2018_12_122_0_4               122         2018           coyote
# f1_fuel_2018_12_122_0_5               122         2018           coyote
# f1_fuel_2018_12_122_0_7               122         2018          neal #4
# f1_fuel_2018_12_122_0_8               122         2018          neal #4
#
#                         fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# record_id
# f1_fuel_2018_12_122_0_2                 oil       bbl           2344.0
# f1_fuel_2018_12_122_0_4                coal       ton         238875.0
# f1_fuel_2018_12_122_0_5                 oil       bbl           2094.0
# f1_fuel_2018_12_122_0_7                coal       ton         137446.0
# f1_fuel_2018_12_122_0_8                 oil       bbl           3251.0
#
#                          fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# ...

# %% [markdown]
# # Data visualization

# %%
#This shows the relationship commonly between used fuel types in each plant
# %matplotlib notebook
plt.pie(df.fuel_type_code_pudl.value_counts(),colors='bcgmrwy',radius=1,data=df,autopct='%.1f%%',startangle=180,labels=df.fuel_type_code_pudl.unique())
plt.title('Pie chart of commonly used fuel types by most plants')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#this shows the number of plants using the different fuel types
plt.figure(figsize=(8,6))
df.fuel_type_code_pudl.value_counts().plot(kind='bar',color=["m", "g",'r','b','y','c'])
plt.xlabel('Fuel types')
plt.ylabel('Number of Plants')
plt.title('Chart showing Number of Plants against Fuel types')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#This plot shows the commonly used fuel units by plants
# %matplotlib notebook
sns.barplot(df.fuel_unit.value_counts().index,df.fuel_unit.value_counts())
plt.xlabel('Fuel units')
plt.ylabel('Number of Plants')
plt.title('Chart showing Number of Plants against Fuel Units')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
sns.boxplot(x="fuel_type_code_pudl", y="utility_id_ferc1",palette=["m", "g",'r','b','y','c'], data=df)
plt.xlabel('Fuel types')
plt.ylabel('utility_id_ferc1')
plt.title('Boxplot of utility_id_ferc1 against fuel types')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#to show the extent of correlation between features and labels in dataset using pearson, kendall or spearman correlation
df.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
#Seaborns heatmap is used to obtain the correlation between features in the dataset
# %matplotlib notebook
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
plt.title('Heatmap of correlation between dataset features')
plt.show()

#Analysis of heatmap
#from the heatmap above, it shows that there is litlle or no correlation between the features in the dataset. This could be as a result of some outliers in the dataset.
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # NUMERICAL FEATURE
# Now I would be focusing on the numerical features to determine the nature of relationships between the data sets

# %%
#to show all features
df.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
#The Seaborn pairplot function shows the relationship betweeen all the numerical features present in the dataset. 
sns.pairplot(df,hue='fuel_type_code_pudl')
# Out:
# <img src="data:image/png;base64,..." width="1903">

# %%
#the skew and kurtosis functions gives an insights on how our data is distributed for each rows.
df.skew()
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
df.kurtosis()
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64
